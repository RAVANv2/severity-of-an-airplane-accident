# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

from collections import Counter

from matplotlib import pyplot

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve

sns.set(style='white', context='notebook', palette='deep')

# %%
train_1 = pd.read_csv("train.csv")
test_1 = pd.read_csv("test.csv")

# %%
train = train_1.copy()
test = test_1.copy()

# %%
train.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
traget = train['Severity']

# %%
train.columns
# Out:
# Index(['Severity', 'Safety_Score', 'Days_Since_Inspection',
#        'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
#        'Cabin_Temperature', 'Accident_Type_Code', 'Max_Elevation',
#        'Violations', 'Adverse_Weather_Metric', 'Accident_ID'],
#       dtype='object')

# %%
numeric_features = ['Safety_Score','Days_Since_Inspection','Total_Safety_Complaints','Control_Metric','Turbulence_In_gforces','Cabin_Temperature','Accident_Type_Code','Max_Elevation','Violations','Adverse_Weather_Metric','Accident_ID']

# %%
#Pairplot
sns.pairplot(train[numeric_features])

# %%
fig = plt.figure(figsize=(24,10))
for i in numeric_features:
    plt.scatter(train[i],train['Severity'])
    plt.xlabel(xlabel=i)
    plt.show()

# %%
train.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Safety_Score'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Days_Since_Inspection'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Total_Safety_Complaints'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Control_Metric'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Turbulence_In_gforces'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Cabin_Temperature'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Accident_Type_Code'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Max_Elevation'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Violations'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Adverse_Weather_Metric'],y=traget,data=train)

# %%
a4_dims = (18,10)
fig,ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(x=train['Accident_ID'],y=traget,data=train)

# %%
train.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
a4_dims = (24,8)
fig,ax = pyplot.subplots(figsize = a4_dims)
sns.stripplot(x=train['Accident_ID'],y=train['Severity'],data = train)
sns.violinplot(x=train['Accident_ID'],y=train['Severity'],data=train)

# %%
a4_dims = (24,8)
fig,ax = pyplot.subplots(figsize = a4_dims)
sns.stripplot(x=train['Total_Safety_Complaints'],y=train['Severity'],data = train)
sns.violinplot(x=train['Total_Safety_Complaints'],y=train['Severity'],data=train)

# %%
a4_dims = (24,8)
fig,ax = pyplot.subplots(figsize = a4_dims)
sns.stripplot(x=train['Total_Safety_Complaints'],y=train['Severity'],data = train)
